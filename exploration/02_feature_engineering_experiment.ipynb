# %% [markdown]
# # EXPLORATION - NOT MAIN PORTFOLIO
# # DATE: 8/2/26
#
# # FINDINGS TO BE ADDED TO MAIN:
# - adding features doesn't improve the performance
# - reducing some low importance V features doesn't reduce the performance either
# - consider removing these low score V features
# - other than the V features, no other engineering will be done to the features
# - scaling also done nothing to the performance, because V-features are already scaled and time & amount did not have as high importance or correlation as the V features

# %% [markdown]
# ## Goal

# %% [markdown]
# Performing feature engineering based on the findings from the initial exploration. Testing a baseline model performance on datasets; baseline and datasets after being engineered. The outcome will be to decide what features should be added or should be removed.

# %% [markdown]
# ### Setup

# %%
import pandas as pd

# %%
data = pd.read_csv('creditcard.csv')

data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# we are still using the raw dataset

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import recall_score, classification_report, precision_score, f1_score
from sklearn.model_selection import train_test_split
import numpy as np

# %% [markdown]
# we use RF for quick test, to determine which feature is useful or not to the final model performance

# %%
X = data.drop('Class', axis=1)
y = data['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=1)

# %% [markdown]
# don't forget stratify so the train & test class distribution match the original -> especially important for fraud where the imbalance is impecable

# %% [markdown]
# ### Baseline Performance

# %%
#just scale the time & amount

scaler = StandardScaler()
X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()
X_train_scaled[['Time', 'Amount']] = scaler.fit_transform(X_train[['Time', 'Amount']])
X_test_scaled[['Time', 'Amount']] = scaler.fit_transform(X_test[['Time', 'Amount']])


model = RandomForestClassifier(n_estimators=100, random_state=1, class_weight='balanced', n_jobs=1)

model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)

print('Baseline Performance')
print(classification_report(y_test, y_pred))

baseline_metrics = {
    'precision' : precision_score(y_test, y_pred),
    'recall' : recall_score(y_test, y_pred),
    'f1' : f1_score(y_test, y_pred)
}
# Out:
# Baseline Performance
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.92      0.85      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.92      0.94     56962
# weighted avg       1.00      1.00      1.00     56962

# %% [markdown]
# ### Experiment 1: Amount - Scaling vs Log Transform

# %% [markdown]
# test if log transform the amount is useful or scaling is enough

# %%
X_train_v1 = X_train.copy()
X_test_v1 = X_test.copy()

X_train_v1['Amount'] = np.log1p(X_train['Amount'])
X_test_v1['Amount'] = np.log1p(X_test['Amount'])

scaler1 = StandardScaler()
X_train_v1[['Time', 'Amount']] = scaler1.fit_transform(X_train_v1[['Time', 'Amount']])
X_test_v1[['Time', 'Amount']] = scaler1.fit_transform(X_test_v1[['Time', 'Amount']])

model.fit(X_train_v1, y_train)
y_pred_v1 = model.predict(X_test_v1)

print('With Log Transformed Amount')
print(classification_report(y_test, y_pred_v1))

log_metrics = {
    'precision' : precision_score(y_test, y_pred_v1),
    'recall' : recall_score(y_test, y_pred_v1),
    'f1' : f1_score(y_test, y_pred_v1)
}

print("\nCOMPARISON:")
print(f"Baseline Recall: {baseline_metrics['recall']:.4f}")
print(f"Log Amount Recall: {log_metrics['recall']:.4f}")
print(f"Improvement: {log_metrics['recall'] - baseline_metrics['recall']:.4f}")
# Out:
# With Log Transformed Amount
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.92      0.85      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.92      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# COMPARISON:
# Baseline Recall: 0.8469
# Log Amount Recall: 0.8469
# Improvement: 0.0000

# %% [markdown]
# log transforming the amount actually produces the same result as just scaling. Because of this, we only going to scale the data without transforming it

# %% [markdown]
# ## Experiment 2: Time Based Feature

# %% [markdown]
# test if engineering hour-based features helps the performance

# %%
#add hour features
X_train_v2 = X_train.copy()
X_test_v2 = X_test.copy()

X_train_v2['hour'] = (X_train_v2['Time']/3600) % 24
X_test_v2['hour'] = (X_test_v2['Time']/3600) % 24

X_train_v2['is_high_risk_hour'] = ((X_train_v2['hour']>=2)&(X_train_v2['hour']>=4)).astype(int)
X_test_v2['is_high_risk_hour'] = ((X_test_v2['hour']>=2)&(X_test_v2['hour']>=4)).astype(int)

#we just scale the data based on exp 1
scaler2 = StandardScaler()
X_train_v2[['Time', 'Amount','hour']] = scaler2.fit_transform(X_train_v2[['Time', 'Amount','hour']])
X_test_v2[['Time', 'Amount','hour']] = scaler2.fit_transform(X_test_v2[['Time', 'Amount','hour']])

model.fit(X_train_v2, y_train)
y_pred_v2 = model.predict(X_test_v2)

print('With Time Features')
print(classification_report(y_test, y_pred_v2))

time_metrics = {
    'precision' : precision_score(y_test, y_pred_v2),
    'recall' : recall_score(y_test, y_pred_v2),
    'f1' : f1_score(y_test, y_pred_v2)
}

print("\nCOMPARISON:")
print(f"Baseline Recall: {baseline_metrics['recall']:.4f}")
print(f"Log Amount Recall: {time_metrics['recall']:.4f}")
print(f"Improvement: {time_metrics['recall'] - baseline_metrics['recall']:.4f}")
# Out:
# With Time Features
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.92      0.85      0.88        98
#
#     accuracy                           1.00     56962
#    macro avg       0.96      0.92      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# COMPARISON:
# Baseline Recall: 0.8469
# Log Amount Recall: 0.8469
# Improvement: 0.0000

# %% [markdown]
# ### Experiment 3: Amount-Based Features

# %% [markdown]
# test micro transactions flag and amount categories

# %%
#add amount features
X_train_v3 = X_train.copy()
X_test_v3 = X_test.copy()

X_train_v3['is_micro'] = (X_train_v3['Amount'] < 10).astype(int)
X_test_v3['is_micro'] = (X_test_v3['Amount'] < 10).astype(int)

X_train_v3[['Time', 'Amount']] = scaler.fit_transform(X_train_v3[['Time', 'Amount']])
X_test_v3[['Time', 'Amount']] = scaler.fit_transform(X_test_v3[['Time', 'Amount']])

model.fit(X_train_v3, y_train)
y_pred_v3 = model.predict(X_test_v3)

print('With Amount Features')
print(classification_report(y_test, y_pred_v3))

amount_metrics = {
    'precision' : precision_score(y_test, y_pred_v3),
    'recall' : recall_score(y_test, y_pred_v3),
    'f1' : f1_score(y_test, y_pred_v3)
}

print("\nCOMPARISON:")
print(f"Baseline Recall: {baseline_metrics['recall']:.4f}")
print(f"Log Amount Recall: {amount_metrics['recall']:.4f}")
print(f"Improvement: {amount_metrics['recall'] - baseline_metrics['recall']:.4f}")
# Out:
# With Amount Features
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.93      0.85      0.89        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.92      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# COMPARISON:
# Baseline Recall: 0.8469
# Log Amount Recall: 0.8469
# Improvement: 0.0000

# %% [markdown]
# ### Experiment 4: Feature Selection - Removing V Features

# %% [markdown]
# based on initial EDA, there are some V features with very small mean differences between classes, meaning they don't really hold much information. This was also further proved by checking the correlation to the target variable, some V features have near 0 correlation.
#
# Let's see if removing them helps with faster training while maintaining or even improve performance. Since none of the features added on previous experiments improved recall, we still going to use initial data.

# %%
low_score_v = ['V22', 'V23', 'V25', 'V26', 'V28', 'V15', 'V24', 'V13', 'V27']

X_train_v4 = X_train.copy()
X_test_v4 = X_test.copy()

X_train_v4 = X_train_v4.drop(columns=low_score_v)
X_test_v4 = X_test_v4.drop(columns=low_score_v)

model.fit(X_train_v4, y_train)
y_pred_v4 = model.predict(X_test_v4)

print("With reduced V")
print(classification_report(y_test, y_pred_v4))

reduced_metrics = {
    'precision' : precision_score(y_test, y_pred_v4),
    'recall' : recall_score(y_test, y_pred_v4),
    'f1' : f1_score(y_test, y_pred_v4)
}

print("\nCOMPARISON:")
print(f"Baseline Recall: {baseline_metrics['recall']:.4f}")
print(f"Log Amount Recall: {reduced_metrics['recall']:.4f}")
print(f"Improvement: {reduced_metrics['recall'] - baseline_metrics['recall']:.4f}")
# Out:
# With reduced V
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.93      0.85      0.89        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.92      0.94     56962
# weighted avg       1.00      1.00      1.00     56962
#
#
# COMPARISON:
# Baseline Recall: 0.8469
# Log Amount Recall: 0.8469
# Improvement: 0.0000

# %% [markdown]
# ## Final Feature Set Summary
# based on the experiment, the final set is:

# %%
# Create comparison table
results_df = pd.DataFrame({
    'Experiment': ['Baseline', 'Log Amount', 'Time Features', 'Amount Features', 'Reduced V'],
    'Precision': [baseline_metrics['precision'], log_metrics['precision'], 
                  time_metrics['precision'], amount_metrics['precision'],
                  reduced_metrics['precision']],
    'Recall': [baseline_metrics['recall'], log_metrics['recall'], 
               time_metrics['recall'], amount_metrics['recall'],
               reduced_metrics['recall']],
    'F1': [baseline_metrics['f1'], log_metrics['f1'], 
           time_metrics['f1'], amount_metrics['f1'],
           reduced_metrics['f1']]
})

print(results_df)
# Out:
#         Experiment  Precision    Recall        F1
# 0         Baseline   0.922222  0.846939  0.882979
# 1       Log Amount   0.922222  0.846939  0.882979
# 2    Time Features   0.922222  0.846939  0.882979
# 3  Amount Features   0.932584  0.846939  0.887701
# 4        Reduced V   0.932584  0.846939  0.887701

# %% [markdown]
# some conclusion:
# - none of the added feature improved the recall / model performance, meaning the V-features from the initial data already carry enough information to predict the test data
# - reducing V features with low score / low correlation did not change the performance, meaning we can remove those features to reduce complexity and making the model run faster.
# - reducing V features also slightly improved the F1 score

# %% [markdown]
# ### Final Decisions:
# - Removed low importance V features
# - No need to add more features
#
# V features will be further tested on the model experiments. If the same V features consistently show up as unimportant across every model, we will remove it in the final model
